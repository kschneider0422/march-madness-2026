# %%
import pandas as pd
import matplotlib.pyplot as plt


tourney_df = pd.read_pickle('pickle/tourney_w_brackets_df.p')

# %%
sweet_sixteen = [] 
for team in tourney_df.columns[:32]:
    if tourney_df[team].min() >= 2:
        sweet_sixteen.append(team)

sweet_sixteen
# Out:
# ['Alabama',
#  'Arizona',
#  'Arkansas',
#  'Connecticut',
#  'Duke',
#  'Houston',
#  'Illinois',
#  'Iowa',
#  'Iowa St.',
#  'Michigan',
#  'Michigan St.',
#  'Nebraska',
#  'Purdue',
#  "St. John's",
#  'Tennessee',
#  'Texas']

# %%
dfs = []
all_labels = []
disp_titles = []


for team in sweet_sixteen:
    print()
    print(team)
    sub_df = tourney_df.loc[tourney_df[team] == 6]
    grouped_df = sub_df[['Winner','Probability']].groupby('Winner').sum().sort_values('Probability', ascending = False)
    grouped_df['Win Probability'] = grouped_df['Probability']/grouped_df['Probability'].sum()
    grouped_df = grouped_df[['Win Probability']]
    grouped_df = grouped_df.loc[grouped_df['Win Probability'] > 0.05]
    other = 1.0 - grouped_df['Win Probability'].sum()
    if other > 0.0001:
        grouped_df.loc['Other'] = [other]
        
    dfs.append(grouped_df)
    labels = list(grouped_df.index)
    all_labels += labels
    
    title = "If " + team + " wins it all."
    disp_titles.append(title)
    
    
    print(grouped_df['Win Probability'])
#     title = "Win probabilty if " + team + " wins it all."
#     ax.pie(grouped_df['Win Probability'], 
#            labels=grouped_df.index,
#            normalize=True,
#            autopct='%1.1f%%')
#     ax.set(ylabel='', title=title, aspect='equal')
# Out:
# Alabama
# Winner
# Ian Thorpe         0.158943
# Patrick Commers    0.144344
# Bobby Ingram       0.135251
# Mark Hurst         0.112060
# Tyler Krause       0.095424
# Danny Ryan         0.077268
# Dan Wros           0.059097
# Other              0.217613
# Name: Win Probability, dtype: float64
#
# Arizona
# Winner
# George Wright      0.473123
# Serigne Diaw       0.276516
# Dan Wros           0.150480
# Justin Calvillo    0.056673
# Other              0.043209
# Name: Win Probability, dtype: float64
#
# Arkansas
# Winner
# Bobby Ingram       0.294041
# Patrick Commers    0.115394
# Ian Thorpe         0.105827
# Keith Schneider    0.076777
# Mark Hurst         0.068519
# Danny Ryan         0.065072
# Other              0.274369
# Name: Win Probability, dtype: float64
#
# Connecticut
# Winner
# Mark Hurst                     0.309257
# Danny Ryan                     0.304304
# Keith Schneider                0.263583
# Keith Schneider, Mark Hurst    0.056318
# Other                          0.066539
# Name: Win Probability, dtype: float64
#
# Duke
# Winner
# Patrick Commers    0.489238
# Tyler Krause       0.261385
# Koy Kubasta        0.249378
# Name: Win Probability, dtype: float64
#
# Houston
# Winner
# Ian Thorpe    1.0
# Name: Win Probability, dtype: float64
#
# Illinois
# Winner
# Patrick Commers    0.278069
# Tyler Krause       0.208819
# Keith Schneider    0.196236
# Bobby Ingram       0.091199
# Mark Hurst         0.081448
# Other              0.144230
# Name: Win Probability, dtype: float64
#
# Iowa
# Winner
# Tyler Krause       0.186097
# Bobby Ingram       0.135144
# Serigne Diaw       0.125629
# Patrick Commers    0.106168
# Keith Schneider    0.103815
# Ian Thorpe         0.062417
# Other              0.280731
# Name: Win Probability, dtype: float64
#
# Iowa St.
# Winner
# Bobby Ingram       0.419639
# Patrick Commers    0.271036
# Danny Ryan         0.057361
# Ian Thorpe         0.054736
# Other              0.197229
# Name: Win Probability, dtype: float64
#
# Michigan
# Winner
# Nathan Sanches    0.907845
# Other             0.092155
# Name: Win Probability, dtype: float64
#
# Michigan St.
# Winner
# Bobby Ingram    0.986233
# Other           0.013767
# Name: Win Probability, dtype: float64
#
# Nebraska
# Winner
# Mark Hurst      0.280937
# Bobby Ingram    0.227032
# Tyler Krause    0.164532
# Ian Thorpe      0.072671
# Serigne Diaw    0.058974
# Other           0.195853
# Name: Win Probability, dtype: float64
#
# Purdue
# Winner
# Tyler Krause    0.763659
# Ian Thorpe      0.067997
# Bobby Ingram    0.064599
# Other           0.103745
# Name: Win Probability, dtype: float64
#
# St. John's
# Winner
# Mark Hurst         0.189897
# Tyler Krause       0.184838
# Danny Ryan         0.148397
# Bobby Ingram       0.147519
# Keith Schneider    0.098241
# Patrick Commers    0.071099
# Ian Thorpe         0.069246
# Other              0.090762
# Name: Win Probability, dtype: float64
#
# Tennessee
# Winner
# Ian Thorpe         0.189366
# Mark Hurst         0.150916
# Patrick Commers    0.127142
# Bobby Ingram       0.111918
# Tyler Krause       0.093654
# Dan Wros           0.089035
# Danny Ryan         0.072068
# Other              0.165902
# Name: Win Probability, dtype: float64
#
# Texas
# Winner
# Bobby Ingram       0.166808
# Ian Thorpe         0.161334
# Patrick Commers    0.153465
# Mark Hurst         0.109006
# Keith Schneider    0.076464
# Danny Ryan         0.058657
# Other              0.274266
# Name: Win Probability, dtype: float64

# %%
def get_color_list(n, step, floor, start=0):
    ang = 2 * pi * step/n
    R = sqrt(1/3)
    k = 1 - floor
    coords = [[sqrt(6) / 3, R * cos(i * ang), R * sin(i * ang)] for i in range(n)]
    M = [[sqrt(3)/3, -sqrt(3)/3, -sqrt(3)/3],
         [sqrt(3)/3, (3+sqrt(3))/6, -(3-sqrt(3))/6],
         [sqrt(3)/3,  -(3-sqrt(3))/6, (3+sqrt(3))/6]]
    colors = []
    for xyz in coords:
        new = [floor + k * sum(a*b for a, b in zip(xyz, row)) for row in M]
        colors.append(new)
        # floor += (1 - floor) / n
        # k = 1 - floor
        x, y, z = xyz        
    return colors

# %%
from math import sin, cos, sqrt, gcd, pi

seen = set()
final_labels = []
for label in all_labels:
    if label not in seen:
        final_labels.append(label)
        seen.add(label)
        
for label in sorted(seen):
    print(label)
        
n = len(final_labels)
step = 1
while gcd(step, n) > 1:
    step += 1
floor = 0.5
colors = get_color_list(n, step, floor, start=0)
color_dict = {label: color for label, color in zip(final_labels, colors)}

color_dict
# Out:
# Bobby Ingram
# Dan Wros
# Danny Ryan
# George Wright
# Ian Thorpe
# Justin Calvillo
# Keith Schneider
# Keith Schneider, Mark Hurst
# Koy Kubasta
# Mark Hurst
# Nathan Sanches
# Other
# Patrick Commers
# Serigne Diaw
# Tyler Krause
# {'Ian Thorpe': [0.5690355937288492, 0.9633731610262555, 0.6746980264314426],
#  'Patrick Commers': [0.5156552436091156,
#   0.9188773201681701,
#   0.7725742174092615],
#  'Bobby Ingram': [0.5003230217561404, 0.8427088473822169, 0.8640749120481901],
#  'Mark Hurst': [0.5256900086171656, 0.7480379635819384, 0.9333788089874432],
#  'Tyler Krause': [0.5873700217120792, 0.6512341246343823, 0.9685026348400858],
#  'Danny Ryan': [0.6746980264314426, 0.5690355937288492, 0.9633731610262555],
#  'Dan Wros': [0.7725742174092615, 0.5156552436091156, 0.9188773201681703],
#  'Other': [0.8640749120481901, 0.5003230217561404, 0.8427088473822169],
#  'George Wright': [0.9333788089874432, 0.5256900086171656, 0.7480379635819385],
#  'Serigne Diaw': [0.9685026348400858, 0.5873700217120792, 0.6512341246343825],
#  'Justin Calvillo': [0.9633731610262556,
#   0.6746980264314426,
#   0.5690355937288493],
#  'Keith Schneider': [0.9188773201681704,
#   0.7725742174092614,
#   0.5156552436091157],
#  'Keith Schneider, Mark Hurst': [0.8427088473822169,
#   0.8640749120481901,
#   0.5003230217561404],
#  'Koy Kubasta': [0.7480379635819385, 0.9333788089874432, 0.5256900086171656],
#  'Nathan Sanches': [0.6512341246343825, 0.9685026348400858, 0.587370021712079]}

# %%
fig, axs = plt.subplots(4, 4, figsize = [24,20])

for ax, title, df in zip(axs.flatten(), disp_titles, dfs):
    labels=df.index
    colors = [color_dict[label] for label in labels]
    labels = [_ for _ in labels]
    ax.pie(df['Win Probability'], 
           labels=labels,
           autopct='%1.1f%%',
           normalize=True,
           colors=colors)
    ax.set(ylabel='', title=title, aspect='equal')

plt.savefig('plots/who_wins_if_who_wins.png', dpi=300, bbox_inches='tight')
