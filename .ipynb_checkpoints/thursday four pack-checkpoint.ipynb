# %%
import pandas as pd
import matplotlib.pyplot as plt


tourney_df = pd.read_pickle('pickle/tourney_w_brackets_df.p')

# %%
winner_df = tourney_df[['Winner', 'Probability']].groupby('Winner').sum()
winner_df
# Out:
#                                                     Probability
# Winner
# Bobby Ingram                                           0.082649
# Bobby Ingram, Ian Thorpe                               0.003860
# Bobby Ingram, Ian Thorpe, Patrick Commers              0.000370
# Bobby Ingram, Patrick Commers                          0.005499
# Dan Wros                                               0.033729
# Dan Wros, Nathan Sanches                               0.000316
# Danny Ryan                                             0.020336
# Danny Ryan, George Wright                              0.001060
# Danny Ryan, George Wright, Keith Schneider             0.000013
# Danny Ryan, George Wright, Keith Schneider, Tyl...     0.000011
# Danny Ryan, George Wright, Mark Hurst                  0.000063
# Danny Ryan, George Wright, Tyler Krause                0.000023
# Danny Ryan, Keith Schneider                            0.001081
# Danny Ryan, Keith Schneider, Mark Hurst                0.000505
# Danny Ryan, Keith Schneider, Mark Hurst, Tyler ...     0.000080
# Danny Ryan, Keith Schneider, Tyler Krause              0.000124
# Danny Ryan, Mark Hurst                                 0.001227
# Danny Ryan, Tyler Krause                               0.000587
# George Wright                                          0.093397
# George Wright, Keith Schneider, Tyler Krause           0.000015
# George Wright, Mark Hurst                              0.001559
# George Wright, Mark Hurst, Tyler Krause                0.000013
# George Wright, Tyler Krause                            0.000857
# Ian Thorpe                                             0.117852
# Ian Thorpe, Patrick Commers                            0.000677
# Justin Calvillo                                        0.012077
# Justin Calvillo, Koy Kubasta                           0.000278
# Justin Calvillo, Serigne Diaw                          0.003332
# Justin Pajela                                          0.001528
# Keith Schneider                                        0.035085
# Keith Schneider, Mark Hurst                            0.004151
# Keith Schneider, Mark Hurst, Tyler Krause              0.000272
# Keith Schneider, Tyler Krause                          0.002728
# Koy Kubasta                                            0.050107
# Koy Kubasta, Serigne Diaw                              0.000271
# Mark Hurst                                             0.034453
# Mark Hurst, Tyler Krause                               0.000059
# Nathan Sanches                                         0.163619
# Patrick Commers                                        0.140068
# Serigne Diaw                                           0.059597
# Tyler Krause                                           0.126473

# %%
from math import pi, cos, sin, sqrt, gcd

def get_color_list(n, step, floor, start=0):
    ang = 2 * pi * step/n
    R = sqrt(1/3)
    k = 1 - floor
    coords = [[sqrt(6) / 3, R * cos(i * ang), R * sin(i * ang)] for i in range(n)]
    M = [[sqrt(3)/3, -sqrt(3)/3, -sqrt(3)/3],
         [sqrt(3)/3, (3+sqrt(3))/6, -(3-sqrt(3))/6],
         [sqrt(3)/3,  -(3-sqrt(3))/6, (3+sqrt(3))/6]]
    colors = []
    for xyz in coords:
        new = [floor + k * sum(a*b for a, b in zip(xyz, row)) for row in M]
        colors.append(new)
        floor += (1 - floor) / n
        k = 1 - floor
        x, y, z = xyz        
    return colors

grouped_df = (tourney_df[['Winner','Probability']].groupby('Winner')
              .sum().sort_values('Probability', ascending = False))
labels = list(grouped_df.index) + ['Other']

n = len(labels)
step = 2
while gcd(step, n) > 1:
    step += 1

floor = 0.1
colors = get_color_list(n, step, floor, start=0)
color_dict = {label: color for label, color in zip(labels, colors)}
color_dict
# Out:
# {'Nathan Sanches': [0.22426406871192844,
#   0.9340716898472599,
#   0.41445644757659683],
#  'Patrick Commers': [0.12171819331190228,
#   0.7559388726038767,
#   0.729116278169154],
#  'Tyler Krause': [0.2401993414912975, 0.4714841218246486, 0.92826194400506],
#  'Ian Thorpe': [0.5132529395976787, 0.23988768031635027, 0.9191870396136199],
#  'George Wright': [0.7967656504482555, 0.1851239117675197, 0.7220493435135964],
#  'Bobby Ingram': [0.947813978350257, 0.3329372905100507, 0.4540462343516977],
#  'Serigne Diaw': [0.8991819982301863, 0.6020353047676841, 0.26370406918527795],
#  'Koy Kubasta': [0.6908722631741349, 0.8515423671500244, 0.25191337585462836],
#  'Keith Schneider': [0.44419259773889, 0.957308391501646, 0.4215334929816138],
#  'Mark Hurst': [0.2946409572376397, 0.8759002618834403, 0.6805162516195902],
#  'Dan Wros': [0.3205444086845176, 0.6634681075532778, 0.8944007290090492],
#  'Danny Ryan': [0.5048847196998048, 0.4417661190726576, 0.958466853016124],
#  'Justin Calvillo': [0.7486666055412219,
#   0.33154308438983415,
#   0.8509766282435165],
#  'Bobby Ingram, Patrick Commers': [0.9264285420425852,
#   0.3895915481340135,
#   0.6406141728033412],
#  'Keith Schneider, Mark Hurst': [0.952950406805348,
#   0.5821281347050018,
#   0.44639776282721066],
#  'Bobby Ingram, Ian Thorpe': [0.8258263144920222,
#   0.8066844291068951,
#   0.3732161249210823],
#  'Justin Calvillo, Serigne Diaw': [0.6228258087086561,
#   0.9488042944932538,
#   0.4577699351152324],
#  'Keith Schneider, Tyler Krause': [0.45754751880482136,
#   0.942328008980878,
#   0.6526340334286538],
#  'George Wright, Mark Hurst': [0.4184654761124,
#   0.8016411267697525,
#   0.8549622544937637],
#  'Justin Pajela': [0.5239521679819639, 0.6103812987572301, 0.9627575606992003],
#  'Danny Ryan, Mark Hurst': [0.7159933726022243,
#   0.47454403221541297,
#   0.9280514553007952],
#  'Danny Ryan, Keith Schneider': [0.8940535376069838,
#   0.4661296299138106,
#   0.779391672118628],
#  'Danny Ryan, George Wright': [0.9695332277132628,
#   0.5871786525562058,
#   0.6033492727118722],
#  'George Wright, Tyler Krause': [0.9114364954839613,
#   0.7720011273036367,
#   0.49662207417037757],
#  'Ian Thorpe, Patrick Commers': [0.7598347568751289,
#   0.9246393130619385,
#   0.5151080151885756],
#  'Danny Ryan, Tyler Krause': [0.6016176215611411,
#   0.9703599612191206,
#   0.6466620717471516],
#  'Danny Ryan, Keith Schneider, Mark Hurst': [0.5229571958579446,
#   0.8936497992835852,
#   0.8206364771352308],
#  'Bobby Ingram, Ian Thorpe, Patrick Commers': [0.5643833540350724,
#   0.7435250967247244,
#   0.9474958912246598],
#  'Dan Wros, Nathan Sanches': [0.7017866645744284,
#   0.6049229839156351,
#   0.9664231615423826],
#  'Justin Calvillo, Koy Kubasta': [0.8620407690165173,
#   0.5526970693604962,
#   0.8757013333213266],
#  'Keith Schneider, Mark Hurst, Tyler Krause': [0.9634642976313945,
#   0.613038709597839,
#   0.7308304699048604],
#  'Koy Kubasta, Serigne Diaw': [0.958842510753136,
#   0.7521030437609395,
#   0.6128799826882545],
#  'Danny Ryan, Keith Schneider, Tyler Krause': [0.8584416274221032,
#   0.896494132670344,
#   0.5849891690812559],
#  'Danny Ryan, Keith Schneider, Mark Hurst, Tyler Krause': [0.7219494728132483,
#   0.9734220152978345,
#   0.6602695141775321],
#  'Danny Ryan, George Wright, Mark Hurst': [0.6250095070131327,
#   0.9486540796934998,
#   0.7973192964798723],
#  'Mark Hurst, Tyler Krause': [0.6190045873610234,
#   0.8425633531615766,
#   0.9243915406832739],
#  'Danny Ryan, George Wright, Tyler Krause': [0.7053909555045463,
#   0.7169310829288147,
#   0.978257455124754],
#  'George Wright, Keith Schneider, Tyler Krause': [0.8372891071475861,
#   0.640765452980942,
#   0.9367968502496318],
#  'Danny Ryan, George Wright, Keith Schneider': [0.9462190119071635,
#   0.6539579040343897,
#   0.8286066037133172],
#  'George Wright, Mark Hurst, Tyler Krause': [0.978847451668589,
#   0.7478411664727498,
#   0.7156952939027014],
#  'Danny Ryan, George Wright, Keith Schneider, Tyler Krause': [0.9241034137188643,
#   0.8719976173331909,
#   0.6595594545147458],
#  'Other': [0.8169672507033316, 0.9625305585232741, 0.6891231409695573]}

# %%
teams = ['Texas',
         'Purdue',
         'Iowa',
         'Nebraska',
         'Arkansas',
         'Arizona',
         'Illinois',
         'Houston']

# %%
dfs = []
all_labels = []
disp_titles = []

fig, axs = plt.subplots(4, 4, figsize = [24,20])
for ax, vec in zip(axs.flatten(), range(15, -1, -1)):
    results = [(vec>>j) % 2 for j in range(4)]
    winners = [teams[2 * a + b] for a, b in zip(range(4), results)]
    sub_df = tourney_df.loc[(tourney_df[winners[0]] > 2) &
                            (tourney_df[winners[1]] > 2) &
                            (tourney_df[winners[2]] > 2) &
                            (tourney_df[winners[3]] > 2)]
    grouped_df = sub_df[['Winner','Probability']].groupby('Winner').sum().sort_values('Probability', ascending = False)
    grouped_df['Win Probability'] = grouped_df['Probability']/grouped_df['Probability'].sum()
    grouped_df = grouped_df[['Win Probability']]
    grouped_df = grouped_df.loc[grouped_df['Win Probability'] > 0.05]
    other = 1.0 - grouped_df['Win Probability'].sum()
    if other > 0.0001:
        grouped_df.loc['Other'] = [other]
    title = f"""What if Thursday's winners are:
{winners[0]}, {winners[1]},
{winners[2]}, and {winners[3]}"""
    labels = list(grouped_df.index)
    colors = [color_dict[label] for label in labels]
    ax.pie(grouped_df['Win Probability'], 
           labels=grouped_df.index,
           normalize=True,
           autopct='%1.1f%%',
           colors=colors)
    ax.set(ylabel='', title=title, aspect='equal')

plt.savefig('plots/thursday_what_if.png', dpi=300, bbox_inches='tight')
